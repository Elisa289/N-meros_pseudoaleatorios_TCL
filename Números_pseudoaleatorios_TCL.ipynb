# %%
import numpy as np

np.random.seed(1) #sembdradios
np.random.random(10) #Genera un numero pseudoaleatorio sobre (0,1)
                     #Muestra aleatoria sobre (0,1)
# Out:
# array([4.17022005e-01, 7.20324493e-01, 1.14374817e-04, 3.02332573e-01,
#        1.46755891e-01, 9.23385948e-02, 1.86260211e-01, 3.45560727e-01,
#        3.96767474e-01, 5.38816734e-01])

# %%
np.random.uniform(-1,1)
# Out:
# -0.1616109711934104

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.DataFrame()
for i in range (1, 50):
  muestra=np.random.binomial(1000,0.6,10)
  col=f"muestra{i}"
  df[col]=muestra
df.head(5)
# Out:
#    muestra1  muestra2  muestra3  muestra4  muestra5  muestra6  muestra7  \
# 0       575       607       612       595       572       624       604
# 1       584       595       628       593       623       615       591
# 2       582       616       603       575       629       609       597
# 3       579       606       583       638       595       616       596
# 4       616       608       596       586       600       596       601
#
#    muestra8  muestra9  muestra10  ...  muestra40  muestra41  muestra42  \
# 0       603       603        636  ...        609        574        590
# 1       614       583        600  ...        604        612        624
# 2       605       597        602  ...        611        614        633
# 3       602       604        573  ...        591        595        604
# 4       587       574        586  ...        594        584        602
#
#    muestra43  muestra44  muestra45  muestra46  muestra47  muestra48  muestra49
# 0        586        591        634        597        615        630        583
# 1        604        608        624        596        614        583        617
# 2        577        611        620        589        600        571        595
# 3        600        619        598        602        598        598        592
# 4        586        593        602        580        583        598        613
#
# [5 rows x 49 columns]

# %%
np.random.binomial(1000,0.6,10)
# Out:
# array([622, 622, 592, 580, 604, 613, 576, 597, 624, 618])

# %%
df_muestra_medias = pd.DataFrame(df.mean(), columns = ["Muestra de las medias"])
df_muestra_medias
# Out:
#            Muestra de las medias
# muestra1                   591.2
# muestra2                   601.8
# muestra3                   605.8
# muestra4                   597.7
# muestra5                   599.1
# muestra6                   607.6
# muestra7                   592.4
# muestra8                   601.4
# muestra9                   596.3
# muestra10                  592.4
# muestra11                  591.5
# muestra12                  601.3
# muestra13                  594.3
# muestra14                  603.8
# muestra15                  607.2
# muestra16                  603.2
# muestra17                  600.5
# muestra18                  607.9
# muestra19                  600.1
# muestra20                  600.8
# muestra21                  603.6
# muestra22                  603.7
# muestra23                  599.5
# muestra24                  602.6
# muestra25                  598.3
# muestra26                  593.1
# muestra27                  607.6
# muestra28                  605.0
# muestra29                  600.8
# muestra30                  604.2
# muestra31                  605.1
# muestra32                  597.7
# muestra33                  595.0
# muestra34                  602.8
# muestra35                  598.0
# muestra36                  593.6
# muestra37                  603.7
# muestra38                  603.1
# muestra39                  594.3
# muestra40                  598.8
# muestra41                  595.7
# muestra42                  600.7
# muestra43                  594.0
# muestra44                  604.1
# muestra45                  603.0
# muestra46                  590.3
# muestra47                  601.0
# muestra48                  600.0
# muestra49                  600.7

# %%
sns.distplot(df_muestra_medias)
# Out:
# <ipython-input-8-064a250483d3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_muestra_medias)
# <Axes: ylabel='Density'>
